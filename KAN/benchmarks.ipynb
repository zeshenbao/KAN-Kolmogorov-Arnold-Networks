# %%
import KAN
import importlib

importlib.reload(KAN)
# Out:
# cpu
# cpu
# <module 'KAN' from '/home/anton/Documents/kth/KAN-Kolmogorov-Arnold-Networks/KAN/KAN.py'>

# %%
importlib.reload(KAN)
def main():
    data = KAN.read_data('../datasets/data2.csv')
    res = KAN.basic_fit(data)
main()
# Out:
# cpu
# checkpoint directory created: ./model
# saving model version 0.0
# | train_loss: 2.84e-01 | test_loss: 2.87e-01 | reg: 8.74e+01 | : 100%|█| 20/20 [00:10<00:00,  1.95it
# saving model version 0.1
# Keys in results: dict_keys(['train_loss', 'test_loss', 'reg'])
# Train Loss: [array(0.63794136, dtype=float32), array(0.54872394, dtype=float32), array(0.516436, dtype=float32), array(0.4966359, dtype=float32), array(0.49083602, dtype=float32), array(0.48041496, dtype=float32), array(0.44850236, dtype=float32), array(0.40580523, dtype=float32), array(0.37396067, dtype=float32), array(0.35204947, dtype=float32), array(0.33820018, dtype=float32), array(0.32815918, dtype=float32), array(0.3176858, dtype=float32), array(0.31241828, dtype=float32), array(0.30347872, dtype=float32), array(0.2980271, dtype=float32), array(0.2939652, dtype=float32), array(0.28927386, dtype=float32), array(0.28642747, dtype=float32), array(0.2836351, dtype=float32)]
# ...
